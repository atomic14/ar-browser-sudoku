# %%
from PIL import Image, ImageDraw, ImageFont, ImageFilter, ImageChops
import pandas as pd
import numpy as np
import pathlib
import os
from fontTools.ttLib import TTFont
from fontTools.unicode import Unicode

# %%
characters = ['1','2','3','4','5','6','7','8','9']
IMG_WIDTH = 100
IMG_HEIGHT = 100
count = 0

# %%
def drawCharacter(path, character, font_path):
    background_color = min(int(200 + np.random.normal() * 20),255)
    foreground_color = int(20 + np.random.normal() * 20)
    image = Image.new("L", (IMG_WIDTH, IMG_HEIGHT), (background_color,))
    draw = ImageDraw.Draw(image)
    font = ImageFont.truetype(font_path, 50)
    w, h = draw.textsize(character, font=font)
    draw.text(((IMG_WIDTH - w) / 2, (IMG_HEIGHT - h) / 2), character, (foreground_color), font=font)
    blurred = image.filter(filter=ImageFilter.GaussianBlur(1))
    
    left = IMG_WIDTH
    top = IMG_HEIGHT
    right = 0
    bottom = 0

    image_pixels = image.load()
    for x in range(image.size[0]):
        for y in range(image.size[1]):    # For every row
            if image_pixels[x,y] != background_color:
                left = min(left, x)
                right = max(right, x)
                top = min(top, y)
                bottom = max(bottom, y)
    
    width = right - left + 4
    height = bottom - top + 4
    x = (left + right)/2
    y = (top + bottom)/2
    
    character_image = blurred.crop((x - width/2, y-height/2, x + width/2, y+height/2))
    pixels = character_image.load() # create the pixel map

    for x in range(character_image.size[0]):
        for y in range(character_image.size[1]):    # For every row
            new_value = pixels[x,y] + np.random.normal() * 2
            pixels[x,y] = (int(new_value),)
    
    character_image.save(f'{path}/{count}.png')

# %%
required_ordinals = [ord(glyph) for glyph in ['1','2','3','4','5','6','7','8','9']]

def supportsDigits(fontPath):
    font = TTFont(fontPath)

    for table in font['cmap'].tables:
        for o in required_ordinals:
            if not o in table.cmap.keys():
                return False
    return True

# %%
image_lookup = [];
font_blacklist = [
    '#',
    "italic",
    "Italic",
    "VAZTEK",
    "antique",
    "aztek",
    "RosewoodStd-Regular",
    "ShishoniBrush",
    "VAVOI",
    "seguili",
    'UVNThayGiaoNang_I',
    'VAVOBI',
    'VNI-Nhatban',
    'VNI-Script',
    'VNI-Trung Kien',
    'segoeuii.ttf',
    'VNI-Viettay',
    'Brush',
    'VREDROCK',
    'UVNHaiBaTrung',
    'UVNButLong',
    'AmaticSC',
    'UVNMucCham',
    'UVNThayGiao_BI.TTF',
    'VKUN',
    'segoeuiz.ttf',
    'seguibli.ttf',
    'MyriadPro',
    'Lobster-Regular',
    'Bangers-Regular',
    'VNI',
    'VUSALI.TTF',
    'VPEINOT.TTF',
    'UVNSangSong_R',
    'VDURHAM.TTF',
    'Vnhltfap.ttf',
    'UVNVienDu',
    'UVNBucThu',
    'UVNSangSong',
    'VSCRIPT',
    'VAUCHON',
    'Vnthfap3',
    'VCAMPAI',
    'BungeeOutline',
    'VBROADW',
    'BungeeHairline-Regular',
    'UVNMinhMap',
    'scripti',
    'UVN',
    'brushsbi',
    'Montserrat',
    'VHELVCI.TTF',
    'VFREE',
    'BRUSH'
    'seguis'
    'VSLOGAN.TTF']

def check_blacklist(font):
    for bl in font_blacklist:
        if bl in font:
            return False
    return True

with open('fonts/fonts.list', 'r') as fonts:
    for font in fonts:
        font = font.strip()
        can_use = supportsDigits(font);
        if can_use and check_blacklist(font):
            for character in characters:
                path = f'testing_data/{character}' if (count % 10) == 0 else f'training_data/{character}'
                image_lookup.append(f'{count}:{font}')
                pathlib.Path(path).mkdir(parents=True, exist_ok=True)
                drawCharacter(path, character, font)
                count = count+1
        else:
            print(f'Skipping {font}')
            
with open("image_to_font_map.txt", "w") as map_file:
    map_file.write("\n".join(image_lookup))
# Out:
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNDaLat_R.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNBucThu.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNThuTu.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNVan_B.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNAnhHai_BI.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNSaigon_BI.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNKyThuat.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNAiCapNhe.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNVanChuongNang_R.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNVietSach_BI.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNHongHaHep_BI.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNSaigon_R.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNHongHa_I.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNViVi.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNThanhBinh.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNMinhMap.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNBayBuomHep_B.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNMoiHong.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/scripti.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNNhan_B.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNThayGiao_I.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNLacLongQuan_B.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNBachTuyet_R.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNDamCuoi_H.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNButLong1.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNHongHa_BI.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNGiaDinhHep_BI.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNVienDu.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNDoiMoi.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNVan_R.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNBachDangNang_R.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNGioMayNhe_R.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNNhatKy_I.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNDaLat_B.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNCatBienNhe_R.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNButLong2.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNBachTuyet_B.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNLacLongQuan_R.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNAnhHaiNhe_I.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNThayGiao_BI.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNTinTuc_I.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNMangCau_I.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNMucCham.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNNhan_R.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNBayBuomHep_R.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNChinhLuan_I.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/antique.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNAnhSang.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNAnhHai_I.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNSaigon_B.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNBayBuom_N.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNGioMay_B.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNGiaDinh_B.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNThangGieng_I.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNBachDang_R.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNBaiSau_R.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNChimBienNang.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNMangTre.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNGiayTrang_R.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNBenXuan_B.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNCatBien_R.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNGiaDinh_BI.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNThoiDai1.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNVietSach_B.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNSangSong_B.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNVanChuong_R.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNBachTuyetNang_I.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNSachVo_B.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNBaiHoc_R.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNHaiLong.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNThoiNay_I.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNHuongQue_N.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNGiaDinhHep_B.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNLaXanh_R.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNConThuy.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNTinTucHepThem_B.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNThayGiaoNang_R.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNHoaDao.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNMangCau_BI.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNTinTucHep_R.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNHongHaHep_B.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNThayGiaoNhe_R.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/brushsbi.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNThoiDai2.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNCatBien_B.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNBenXuan_R.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNBoQuen.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNBuiDoi.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNAiCapNang.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNKeChuyen3.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNGiayTrang_B.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNThanhPhoNang.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNBaiSau_B.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNKeChuyen2.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNMauTim2.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNBachDang_B.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNGiaDinh_R.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNHaiBaTrung.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNMangCauNang_R.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNGiongSong_BI.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNPhuongTay.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNGioMay_R.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNNguyenDu.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNThoiNayNang_R.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNNhanNang_R.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNHongHaHep_R.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNTinTucHep_B.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNMayChuP_I.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNMotMoi.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNTinTucHepThem_R.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNLaXanh_B.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNKeChuyen1.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNGiongSong_I.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNMauTim1.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNGiaDinhHep_R.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNThoiNay_BI.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNSachVo_R.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNTinTucHep_BI.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNBaiHoc_B.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNTinTucNhe_I.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNChinhLuan_BI.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNVanChuong_B.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNVietSach_R.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNSangSong_R.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNNhanNang_I.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNThoiNayNang_I.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNBachDang_BI.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNHongHaHep_I.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNMayChuP_R.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNGiaDinhHep_I.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNGiongSong_R.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNHuongQue_R.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNThoiNay_B.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNSachVo_I.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNTinTucNhe_R.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNThangVu.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNVietSach_I.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNKieu_B.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNHanViet.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/aztekb.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNNhatKy_BI.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNBaiSau_N.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNHoaTay1.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNGiaDinh_I.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNCoDien_R.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNMangCauNang_I.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNThanhPho_B.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNGioMay_I.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNVanChuong_I.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNSangSong_N.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNBachTuyetNang_R.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNBanhMi.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNBachTuyet_BI.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNBaiHoc_I.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNThoiNay_R.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNMayChuP_BI.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNHuongQue_B.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNGiongSong_B.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNNhan_BI.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNLaXanh_I.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNLYDO_.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNThayGiaoNang_I.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNMayChuP_B.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNLaXanh_BI.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNTinTucHep_I.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNThayGiaoNhe_I.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNThanhPho_R.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNCoDien_B.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNThangGieng_R.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNBaiHoc_BI.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNBachDang_I.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNDzungDakao.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNKieu_R.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNCatBien_I.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNAnhHaiNhe_R.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNThayGiao_B.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNBaLe.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNTinTuc_R.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNAiCap_R.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNVungTau.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNMangCau_R.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNNhan_I.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNChinhLuan_R.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNAnhHai_R.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNChimBien_B.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNHongHa_B.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNSachVo_BI.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNBayBuom_B.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNTinTuc_BI.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNDungDan.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNCHUKY.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNDinhHon.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNBinhDuong.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNBachDangNang_I.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNNhatKy_R.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNGioMayNhe_I.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNHOAKY.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNCatBienNhe_I.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNDamCuoi_R.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNBayBuom_R.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNHongHa_R.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNSaigon_I.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNChimBien_R.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNAnhHai_B.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNCatBien_BI.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNChinhLuan_B.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNBayBuomHep_N.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNGioMay_BI.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNMangCau_B.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNAiCap_B.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNTinTuc_B.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNThayGiao_R.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNBanTay.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNBachTuyet_I.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNNhatKy_B.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNBaiSau_Nh.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNMuaThu.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/unicode/UVNChimBienNhe.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VNI-OngdoHL.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VNI-Truck.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VAVOBI.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VNI-Alex.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VNI-Sandy.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VNI-Machina.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VBROADW.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VFREEWN.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VNI-Yahoo.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VNI-Zap.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VKUNB.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VNI-Matisse.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VNI-Briquet.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VNI-Jamai.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VNIDOS.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VNI-Top.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VNI-Netbut.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VNI-Qwigley.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VNI-Springtime.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VNI-Zirkon.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VCAMPAI.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VAUCHON.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VFREEWI.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/Vnthfap3.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VSCRIPT.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VNI-Thuphap.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VNI-Whimsy.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VNI-AmbianceBTSwash.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VNI-Love.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VNI-HelveB.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VNI-Souvir.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VNI-Annabelle.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VNI-JackieO.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VNI-Saliere.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VNI-Thanhcao.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VNI-Linus.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VNI-Thuphap3.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VNIWIN.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VNI-Lithos.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VNI-Thuphap2.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VNI-Mandalay.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VNI-Univer.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VNI-AlexBrush.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VNI-Thuphap1.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VAZTEK.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VNI-Silver.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VNI-Script.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VNI-Tubes.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VNI-HelveI.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VNI-Chops Normal.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VNI-Viettay.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VHELVCI.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VFREE.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VNI-Diudang.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VNI-Trung Kien.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VKUNBI.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VNI-BrushMe.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VNI-Butlong.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VNI-Slogan.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VNI-KorinB.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VNI-Korin.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VNI-Disney.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VPEINOT.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VNI-Thufapfan.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VNI-Vivi.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VNI-Bendigo.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VNI-Maria.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VNI-Baybuom.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VNI-Walt Disney.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VREDROCK.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/Vnhltfap.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VNI-ShishoniBrush.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VDURHAM.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VNI-Hobo.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VFREEWBI.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VFREEWB.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VAVOI.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VKUNN.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VNI-Nhatban.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VNI-Scrap Cursive.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VNI-HelveBI.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VNI-University.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VUSALI.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/vi/vni/VKUNM.TTF
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/win/MyriadPro-BoldCondIt.otf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/win/segoeuii.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/win/seguili.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/win/segoeuiz.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/win/MyriadPro-It.otf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/win/MyriadPro-Bold.otf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/win/MyriadPro-CondIt.otf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/win/seguibli.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/win/MyriadPro-BoldIt.otf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/win/RosewoodStd-Regular.otf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/win/MyriadPro-BoldCond.otf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/win/MyriadPro-Cond.otf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Amatic_SC/AmaticSC-Regular.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Amatic_SC/AmaticSC-Bold.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Tinos/Tinos-Italic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Tinos/Tinos-BoldItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Asap/Asap-BoldItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Asap/Asap-MediumItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Asap/Asap-SemiBoldItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Asap/Asap-Italic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Alegreya_Sans/AlegreyaSans-Italic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Cormorant_Infant/CormorantInfant-BoldItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Cormorant_Infant/CormorantInfant-Italic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Cormorant_Infant/CormorantInfant-SemiBoldItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Cormorant_Infant/CormorantInfant-LightItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Cormorant_Infant/CormorantInfant-MediumItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Manuale/Manuale-Italic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Manuale/Manuale-MediumItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Manuale/Manuale-BoldItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Manuale/Manuale-SemiBoldItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Fira_Sans/FiraSans-ExtraLightItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Fira_Sans/FiraSans-LightItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Fira_Sans/FiraSans-BoldItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Fira_Sans/FiraSans-ThinItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Fira_Sans/FiraSans-MediumItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Fira_Sans/FiraSans-BlackItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Fira_Sans/FiraSans-SemiBoldItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Fira_Sans/FiraSans-ExtraBoldItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Fira_Sans/FiraSans-Italic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Arsenal/Arsenal-Italic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Arsenal/Arsenal-BoldItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Space_Mono/SpaceMono-BoldItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Space_Mono/SpaceMono-Italic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Bungee_Outline/BungeeOutline-Regular.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Arimo/Arimo-Italic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Arimo/Arimo-BoldItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Lobster/Lobster-Regular.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Exo/Exo-SemiBoldItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Exo/Exo-MediumItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Exo/Exo-BoldItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Exo/Exo-ThinItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Exo/Exo-ExtraBoldItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Exo/Exo-ExtraLightItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Exo/Exo-LightItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Exo/Exo-BlackItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Exo/Exo-Italic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Philosopher/Philosopher-BoldItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Philosopher/Philosopher-Italic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Spectral/Spectral-BoldItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Spectral/Spectral-MediumItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Spectral/Spectral-ExtraLightItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Spectral/Spectral-ExtraBoldItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Spectral/Spectral-LightItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Spectral/Spectral-Italic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Spectral/Spectral-SemiBoldItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Asap_Condensed/AsapCondensed-MediumItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Asap_Condensed/AsapCondensed-SemiBoldItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Asap_Condensed/AsapCondensed-BoldItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Asap_Condensed/AsapCondensed-Italic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Open_Sans_Condensed/OpenSansCondensed-LightItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Cuprum/Cuprum-Italic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Cuprum/Cuprum-BoldItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Cousine/Cousine-BoldItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Cousine/Cousine-Italic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Josefin_Sans/JosefinSans-Italic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Josefin_Sans/JosefinSans-LightItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Josefin_Sans/JosefinSans-BoldItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Josefin_Sans/JosefinSans-ThinItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Josefin_Sans/JosefinSans-SemiBoldItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Cabin/Cabin-SemiBoldItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Cabin/Cabin-MediumItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Cabin/Cabin-BoldItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Cabin/Cabin-Italic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Prompt/Prompt-ThinItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Prompt/Prompt-BlackItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Prompt/Prompt-MediumItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Prompt/Prompt-BoldItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Prompt/Prompt-LightItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Prompt/Prompt-ExtraLightItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Prompt/Prompt-SemiBoldItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Prompt/Prompt-ExtraBoldItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Prompt/Prompt-Italic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Noto_Sans/NotoSans-BoldItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Noto_Sans/NotoSans-Italic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Vollkorn/Vollkorn-BlackItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Vollkorn/Vollkorn-Italic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Vollkorn/Vollkorn-BoldItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Vollkorn/Vollkorn-SemiBoldItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Montserrat/Montserrat-LightItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Montserrat/Montserrat-Medium.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Montserrat/Montserrat-BoldItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Montserrat/Montserrat-Light.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Montserrat/Montserrat-ThinItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Montserrat/Montserrat-ExtraLight.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Montserrat/Montserrat-Thin.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Montserrat/Montserrat-Bold.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Montserrat/Montserrat-MediumItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Montserrat/Montserrat-BlackItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Montserrat/Montserrat-SemiBold.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Montserrat/Montserrat-ExtraLightItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Montserrat/Montserrat-ExtraBold.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Montserrat/Montserrat-Black.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Montserrat/Montserrat-Regular.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Montserrat/Montserrat-Italic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Montserrat/Montserrat-SemiBoldItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Montserrat/Montserrat-ExtraBoldItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Open_Sans/OpenSans-Italic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Open_Sans/OpenSans-LightItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Open_Sans/OpenSans-SemiBoldItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Open_Sans/OpenSans-ExtraBoldItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Open_Sans/OpenSans-BoldItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Archivo/Archivo-MediumItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Archivo/Archivo-SemiBoldItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Archivo/Archivo-BoldItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Archivo/Archivo-Italic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Kanit/Kanit-ThinItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Kanit/Kanit-BoldItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Kanit/Kanit-Italic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Kanit/Kanit-MediumItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Kanit/Kanit-ExtraBoldItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Kanit/Kanit-SemiBoldItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Kanit/Kanit-BlackItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Kanit/Kanit-LightItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Kanit/Kanit-ExtraLightItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Roboto/Roboto-MediumItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Roboto/Roboto-ThinItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Roboto/Roboto-BoldItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Roboto/Roboto-LightItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Roboto/Roboto-Italic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Roboto/Roboto-BlackItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Lora/Lora-Italic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Lora/Lora-BoldItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Fira_Sans_Extra_Condensed/FiraSansExtraCondensed-MediumItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Fira_Sans_Extra_Condensed/FiraSansExtraCondensed-Italic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Fira_Sans_Extra_Condensed/FiraSansExtraCondensed-BlackItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Fira_Sans_Extra_Condensed/FiraSansExtraCondensed-LightItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Fira_Sans_Extra_Condensed/FiraSansExtraCondensed-BoldItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Fira_Sans_Extra_Condensed/FiraSansExtraCondensed-ThinItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Fira_Sans_Extra_Condensed/FiraSansExtraCondensed-ExtraLightItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Fira_Sans_Extra_Condensed/FiraSansExtraCondensed-SemiBoldItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Fira_Sans_Extra_Condensed/FiraSansExtraCondensed-ExtraBoldItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Source_Sans_Pro/SourceSansPro-BlackItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Source_Sans_Pro/SourceSansPro-SemiBoldItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Source_Sans_Pro/SourceSansPro-LightItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Source_Sans_Pro/SourceSansPro-BoldItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Source_Sans_Pro/SourceSansPro-ExtraLightItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Source_Sans_Pro/SourceSansPro-Italic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Noticia_Text/NoticiaText-BoldItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Noticia_Text/NoticiaText-Italic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Judson/Judson-Italic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Bangers/Bangers-Regular.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Faustina/Faustina-SemiBoldItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Faustina/Faustina-BoldItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Faustina/Faustina-Italic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Faustina/Faustina-MediumItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Fira_Sans_Condensed/FiraSansCondensed-SemiBoldItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Fira_Sans_Condensed/FiraSansCondensed-ExtraLightItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Fira_Sans_Condensed/FiraSansCondensed-MediumItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Fira_Sans_Condensed/FiraSansCondensed-LightItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Fira_Sans_Condensed/FiraSansCondensed-ExtraBoldItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Fira_Sans_Condensed/FiraSansCondensed-BoldItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Fira_Sans_Condensed/FiraSansCondensed-Italic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Fira_Sans_Condensed/FiraSansCondensed-ThinItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Fira_Sans_Condensed/FiraSansCondensed-BlackItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Roboto_Condensed/RobotoCondensed-Italic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Roboto_Condensed/RobotoCondensed-BoldItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Roboto_Condensed/RobotoCondensed-LightItalic.ttf
# Skipping /Users/chrisgreening/Work/projects/sudoku-grab/tensorflow/fonts/google/Bungee_Hairline/BungeeHairline-Regular.ttf
